# %%
import pandas as pd
import numpy as np
data=pd.read_csv('TITAN.NS__.csv')
# Concatenate all DataFrames in the list into a single DataFrame


# Display basic information about the DataFrame
print("Basic Info:")
print(data.info())
# Out:
# Basic Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1477 entries, 0 to 1476
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               1477 non-null   object
#  1   Open               1477 non-null   float64
#  2   High               1477 non-null   float64
#  3   Low                1477 non-null   float64
#  4   Close              1477 non-null   float64
#  5   Adj Close          1477 non-null   float64
#  6   Volume             1477 non-null   int64
#  7   Change_Percentage  1476 non-null   float64
#  8   Change_Price       1476 non-null   float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 104.0+ KB
# None

# %%
import pandas as pd import numpy as np
# Load csv files
for file in csv_files:
csv_files =  ['TITAN.CSV', 'RELIANCE.CSV', 'ASIANPAINT.CSV', 'HEROMOTOCO.CSV', 'L&T.csv', 'TCS.CSV']
df = pd. read_csv (file)
#add cloumn for change in percentage to from prevoius clossing price
df ['Change_Percentage'] = df ['Close'] -pct_change() * 100
#add cloumn for change in price to from prevoius clossing price
df [ 'Change_Price'] = df['Close'] - df ['Close']. shift (1)
#Save the updated DataFrame back to a new CSV file with the original name
output_file = os. spath.splitext(file) [0] + '
・cSV'
df. to_csv(output_file, index=False)
# Display the updated DataFrame
print(f"Updated DataFrame for {file}:")
print (df)
print ('\n'

# %%
import pandas as pd
import os

# List of file paths
csv_files =  ['TITAN.CSV', 'RELIANCE.CSV', 'ASIANPAINT.CSV', 'HEROMOTOCO.CSV', 'L&T.csv', 'TCS.CSV']

# Load csv files into DataFrames, round off point values, and save back to CSV
for file in csv_files:
    # Load CSV into DataFrame
    df = pd.read_csv(file)

    # Round off point values to two decimal places
    df = df.round(2)

    # Save the updated DataFrame back to a new CSV file with the original name
    output_file = os.path.splitext(file)[0] + '_rounded.csv'
    df.to_csv(output_file, index=False)

    # Display the updated DataFrame
    print(f"Updated DataFrame for {file}:")
    print(df)
    print('\n')
# Out:
# Updated DataFrame for TITAN.CSV:
#             Date     Open     High      Low    Close  Adj Close   Volume  \
# 0     2018-01-01   857.70   862.05   851.05   852.45     833.98   472607
# 1     2018-01-02   854.10   858.45   840.60   845.15     826.84  1181949
# 2     2018-01-03   863.90   869.40   853.00   856.30     837.75  2606556
# 3     2018-01-04   864.40   897.45   853.10   892.90     873.56  3028931
# 4     2018-01-05   895.00   913.95   893.50   909.70     889.99  4036882
# ...          ...      ...      ...      ...      ...        ...      ...
# 1472  2023-12-18  3600.70  3667.20  3593.90  3619.60    3619.60   699850
# 1473  2023-12-19  3610.65  3627.95  3600.10  3610.45    3610.45   577926
# 1474  2023-12-20  3610.45  3651.50  3541.00  3554.10    3554.10   849001
# 1475  2023-12-21  3524.10  3598.95  3518.80  3580.00    3580.00   816722
# 1476  2023-12-22  3580.00  3638.45  3560.55  3627.35    3627.35   777099
#
#       Change_Percentage  Change_Price
# ...

# %%
import pandas as pd

# List of file paths

file_paths = ['TITAN.CSV', 'RELIANCE.CSV', 'ASIANPAINT.CSV', 'HEROMOTOCO.CSV', 'L&T.csv', 'TCS.CSV']
# Initialize an empty list to store DataFrames
dfs = []
# Loop through each file and append its DataFrame to the list
for file_path in file_paths:
    df = pd.read_csv (file_path)
    dfs. append (df)
    
# Concatenate all DataFrames in the list into a single DataFrame
data = pd.concat(dfs, ignore_index=True)
# Print the null values in the combined DataFrame
print(data.isnull().sum())
# Out:
# Date                 0
# Open                 0
# High                 0
# Low                  0
# Close                0
# Adj Close            0
# Volume               0
# Change_Percentage    6
# Change_Price         6
# dtype: int64

# %%
import seaborn as sns

# Box plot of closing prices
sns.boxplot(x=data['Close'])
plt.title('Box Plot of Closing Prices')
plt.show()

# %%
Q1 = data['Close'].quantile(0.25)
Q3 = data['Close'].quantile(0.75)
IQR = Q3 - Q1

# Identify potential outliers
outliers = (data['Close'] < Q1 - 1.5 * IQR) | (data['Close'] > Q3 + 1.5 * IQR)
print("Potential Outliers:")
print(data[outliers])
# Out:
# Potential Outliers:
# Empty DataFrame
# Columns: [Date, Open, High, Low, Close, Adj Close, Volume, Change_Percentage, Change_Price]
# Index: []

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import itertools

# List of file paths
file_paths = ['TITAN.CSV', 'RELIANCE.CSV', 'ASIANPAINT.CSV', 'HEROMOTOCO.CSV', 'L&T.csv', 'TCS.CSV']

# Initialize an empty list to store DataFrames
dfs = []

# Loop through each file and append its DataFrame to the list
for file_path in file_paths:
    df = pd.read_csv(file_path)
    # Assuming 'Date' is a column in your DataFrame
    df['Date'] = pd.to_datetime(df['Date'])
    dfs.append(df)

# Concatenate all DataFrames in the list into a single DataFrame
data = pd.concat(dfs, ignore_index=True)

# Create a color map for each stock
colors = iter(plt.cm.rainbow(np.linspace(0, 1, len(file_paths))))

# Create a list to store colors for individual line charts
line_chart_colors = []

plt.figure(figsize=(28, 14))

for file_path in file_paths:
    df = pd.read_csv(file_path)
    color = next(colors)
    line_chart_colors.append(color)
    plt.plot(df['Date'], df['Close'], label=file_path, color=color)

plt.title(f'Closing Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.legend()
plt.show()

# Plot individual line charts with the same color as the combined chart
num_rows = 3
num_cols = 2
num_charts = min(len(file_paths), num_rows * num_cols)

for i in range(num_charts):
    plt.figure(figsize=(20, 15))
    for j in range(num_rows):
        for k in range(num_cols):
            chart_index = i * num_rows * num_cols + j * num_cols + k
            if chart_index < len(file_paths):
                file_path = file_paths[chart_index]
                df = pd.read_csv(file_path)
                color = line_chart_colors[chart_index]
                plt.subplot(num_rows, num_cols, j * num_cols + k + 1)
                plt.plot(df['Date'], df['Close'], label=file_path, color=color)
                plt.title(f'Closing Prices Over Time - {file_path}')
                plt.xlabel('Date')
                plt.ylabel('Closing Price')
                plt.legend()

    plt.tight_layout()
    plt.show()

# %%
import seaborn as sns
# Create a color map for each stock
colors = plt.cm.rainbow(np.linspace(0, 1, len(file_paths)))

# Plot histograms for Closing Prices
num_rows = 3
num_cols = 2
num_charts = min(len(file_paths), num_rows * num_cols)

for i in range(num_charts):
    plt.figure(figsize=(20, 15))
    for j in range(num_rows):
        for k in range(num_cols):
            chart_index = i * num_rows * num_cols + j * num_cols + k
            if chart_index < len(file_paths):
                file_path = file_paths[chart_index]
                df = pd.read_csv(file_path)
                color = colors[chart_index]
                plt.subplot(num_rows, num_cols, j * num_cols + k + 1)
                sns.histplot(df['Close'], bins=30, kde=True, color=color, label=file_path)
                plt.title(f'Histogram of Closing Prices')
                plt.xlabel('Closing Price')
                plt.ylabel('Frequency')

                # Calculate and display central tendency and dispersion measures
                mean_price = df['Close'].mean()
                median_price = df['Close'].median()
                std_dev = df['Close'].std()
                average_price = df['Close'].mean()

                plt.axvline(mean_price, color='r', linestyle='dashed', linewidth=2, label=f'Mean: {mean_price:.2f}')
                plt.axvline(median_price, color='g', linestyle='dashed', linewidth=2, label=f'Median: {median_price:.2f}')
                plt.axvline(average_price, color='purple', linestyle='dashed', linewidth=2, label=f'Average: {average_price:.2f}')
                plt.axvline(mean_price + std_dev, color='b', linestyle='dashed', linewidth=2, label=f'Std Dev: {std_dev:.2f}')
                plt.axvline(mean_price - std_dev, color='b', linestyle='dashed', linewidth=2)

                # Add legend for each subplot
                plt.legend()

    plt.tight_layout()
    plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import itertools

# List of file paths and corresponding symbols
file_symbol_mapping = {'TITAN.CSV': 'TITAN', 'RELIANCE.CSV': 'RELIANCE', 'ASIANPAINT.CSV': 'ASIANPAINT',
                        'HEROMOTOCO.CSV': 'HEROMOTOCO', 'L&T.csv': 'L&T', 'TCS.CSV': 'TCS'}

# Initialize an empty list to store DataFrames
dfs = []

# Loop through each file and append its DataFrame to the list
for file_path, symbol in file_symbol_mapping.items():
    df = pd.read_csv(file_path)
    df['Symbol'] = symbol  # Add a new column for the symbol
    df['Date'] = pd.to_datetime(df['Date'])
    dfs.append(df)

# Concatenate all DataFrames in the list into a single DataFrame
data = pd.concat(dfs, ignore_index=True)

# Calculate 200-day moving average for each stock
data['200_MA'] = data.groupby('Symbol')['Close'].transform(lambda x: x.rolling(window=200).mean())

# Create a 3x2 grid layout for combined charts
fig_combined, axs_combined = plt.subplots(3, 2, figsize=(20, 15))

# Create a color map for each stock
colors = iter(plt.cm.rainbow(np.linspace(0, 1, len(file_symbol_mapping))))

for i, (file_path, symbol) in enumerate(file_symbol_mapping.items()):
    row, col = divmod(i, 2)
    symbol_data = data[data['Symbol'] == symbol]
    color = next(colors)

    axs_combined[row, col].plot(symbol_data['Date'], symbol_data['Close'], label='Close', color=color)
    axs_combined[row, col].plot(symbol_data['Date'], symbol_data['200_MA'], label='200-MA', linestyle='--', color=color)

    axs_combined[row, col].set_title(f'{symbol}')
    axs_combined[row, col].set_xlabel('Date')
    axs_combined[row, col].set_ylabel('Price')
    axs_combined[row, col].xaxis.set_major_locator(MaxNLocator(nbins=6))  # Adjust x-axis ticks for better readability
    axs_combined[row, col].legend()

    # Label the stock name on the chart
    axs_combined[row, col].annotate(symbol, xy=(0.02, 0.9), xycoords='axes fraction', fontsize=10, color=color)

# Adjust layout for combined charts
plt.tight_layout()
plt.show()

# Plot individual line charts with the same color as the combined chart
num_rows = 3
num_cols = 2
num_charts = min(len(file_symbol_mapping), num_rows * num_cols)

for i in range(num_charts):
    plt.figure(figsize=(20, 15))
    for j in range(num_rows):
        for k in range(num_cols):
            chart_index = i * num_rows * num_cols + j * num_cols + k
            if chart_index < len(file_symbol_mapping):
                file_path, symbol = list(file_symbol_mapping.items())[chart_index]
                symbol_data = data[data['Symbol'] == symbol]
                color = next(colors)
                plt.subplot(num_rows, num_cols, j * num_cols + k + 1)
                plt.plot(symbol_data['Date'], symbol_data['Close'], label=f'{symbol} Close', color=color)
                plt.plot(symbol_data['Date'], symbol_data['200_MA'], label=f'{symbol} 200-MA', linestyle='--', color=color)
                plt.title(f'Closing Prices and 200-Day MA - {symbol}')
                plt.xlabel('Date')
                plt.ylabel('Price')
                plt.legend()

    plt.tight_layout()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[8], line 66
#      64 file_path, symbol = list(file_symbol_mapping.items())[chart_index]
#      65 symbol_data = data[data['Symbol'] == symbol]
# ---> 66 color = next(colors)
#      67 plt.subplot(num_rows, num_cols, j * num_cols + k + 1)
#      68 plt.plot(symbol_data['Date'], symbol_data['Close'], label=f'{symbol} Close', color=color)
#
# StopIteration:

# %%
# Plot scatter plot of Closing Prices against Volume in a 3 by 3 layout with different colors
num_rows = 3
num_cols = 2
num_charts = min(len(file_paths), num_rows * num_cols)

fig, axs = plt.subplots(num_rows, num_cols, figsize=(20, 16))

# Define a list of colors for individual stocks
scatter_colors = ['red', 'green', 'blue', 'orange', 'purple', 'cyan']

for i in range(num_charts):
    row_index = i // num_cols
    col_index = i % num_cols
    file_path = file_paths[i]
    df = pd.read_csv(file_path)

    axs[row_index, col_index].scatter(df['Close'], df['Volume'], color=scatter_colors[i])
    axs[row_index, col_index].set_title(f'Scatter Plot - {file_path}')
    axs[row_index, col_index].set_xlabel('Closing Price')
    axs[row_index, col_index].set_ylabel('Volume')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# List of file paths
file_paths = ['TITAN.CSV', 'RELIANCE.CSV', 'ASIANPAINT.CSV', 'HEROMOTOCO.CSV', 'L&T.csv', 'TCS.CSV']

# Loop through each file path
for file_path in file_paths:
    # Read the data for the current stock
    df = pd.read_csv(file_path)
    
    # Assuming 'Date' is a column in your DataFrame
    df['Date'] = pd.to_datetime(df['Date'])

    # Create a pair plot for the current stock
    sns.set(style="ticks", color_codes=True)
    sns.pairplot(df[['Open', 'High', 'Low', 'Close']])
    plt.suptitle(f'Pair Plot for {file_path.split(".")[0]} - Open, High, Low, Close', y=1.02)
    plt.show()
# Out:
# /Users/vijaychoudhary/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/vijaychoudhary/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/vijaychoudhary/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/vijaychoudhary/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/vijaychoudhary/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# ...

# %%
# Loop through each file and append its DataFrame to the list
for file_path in file_paths:
    df = pd.read_csv(file_path)
    # Assuming 'Date' is a column in your DataFrame
    df['Date'] = pd.to_datetime(df['Date'])
    # Create a new column 'Stock' with the stock name (or any other relevant grouping variable)
    df['Stock'] = file_path.split('.')[0]
    dfs.append(df)

# Concatenate all DataFrames in the list into a single DataFrame
data = pd.concat(dfs, ignore_index=True)

# Create a box plot of Closing Prices by Stock
plt.figure(figsize=(14, 8))
sns.boxplot(x='Stock', y='Close', data=data)
plt.title('Box Plot of Closing Prices by Stock')
plt.xlabel('Stock')
plt.ylabel('Closing Price')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Loop through each file and append its DataFrame to the list
# ----> 2 for file_path in file_paths:
#       3     df = pd.read_csv(file_path)
#       4     # Assuming 'Date' is a column in your DataFrame
#
# NameError: name 'file_paths' is not defined

# %%
# Create a 2x3 grid of subplots (2 subplots for each stock, 1 for the overall heatmap)
fig, axes = plt.subplots(2, 3, figsize=(20, 10), sharex=True, sharey=True)

# Flatten the 2x3 array of subplots
axes = axes.flatten()

# Loop through each stock and create a heatmap for the percentage change in 2023
for i, (file_path, subset) in enumerate(data.groupby(['File'])):
    file = file_path[0]  # Extract file name
    subset_2023 = subset[subset['Year'] == 2023]
    subset_pivot = subset_2023.pivot(index='Date', columns='File', values='Percentage Change')
    
    # Get the color for the current stock
    color = stock_colors[file]
    
    # Create a custom colormap for the stock
    cmap = ListedColormap(sns.color_palette([color]))

    # Create a heatmap with custom colors for the percentage change in 2023
    sns.heatmap(subset_pivot.resample('Y').last()/ 100, ax=axes[i], cmap=cmap, annot=True, fmt=".2%", cbar=True, cbar_kws={'label': 'Percentage Change'}, annot_kws={'size': 20})
   
    axes[i].set_title(f"{file.split('.')[0]} - 2018-2023")  # Set subplot title

    # Remove side number ruler and date labels
    axes[i].yaxis.set_visible(False)
    axes[i].xaxis.set_visible(False)

    # Annotate with the stock name
    axes[i].annotate(file.split('.')[0], xy=(0.5, 0.5), xytext=(0, 50), textcoords="offset points", ha='center', va='center', fontsize=20, color='white')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.colors import ListedColormap

# List of file paths
file_paths = ['TITAN.CSV', 'RELIANCE.CSV', 'ASIANPAINT.CSV', 'HEROMOTOCO.CSV', 'L&T.csv', 'TCS.CSV']
# Initialize an empty list to store DataFrames
dfs = []

# Define colors for each stock
stock_colors = {
    'TITAN.CSV': '#86C8BC',
    'RELIANCE.CSV': '#C07F00',
    'ASIANPAINT.CSV': '#E36414',
    'HEROMOTOCO.CSV': 'red',
    'L&T.csv': '#11235A',
    'TCS.CSV': '#DA0C81'
}

for file_path in file_paths:
    try:
        # Read each CSV file into a DataFrame
        df = pd.read_csv(file_path)
        
        # Convert 'Date' column to datetime
        df['Date'] = pd.to_datetime(df['Date'])
        
        # Calculate the percentage change for the closing price
        df['Percentage Change'] = ((df['Close'] - df['Close'].iloc[0]) / df['Close'].iloc[0]) * 100
        
        # Extract the year from the 'Date' column
        df['Year'] = df['Date'].dt.year
        
        # Add a new column with the file name
        df['File'] = file_path
        
        # Append the DataFrame to the list
        dfs.append(df)
    except Exception as e:
        print(f"Error reading file {file_path}: {e}")

# Concatenate all DataFrames in the list into a single DataFrame
data = pd.concat(dfs, ignore_index=True)

# Create a 3x3 grid of subplots
fig, axes = plt.subplots(12, 3, figsize=(20, 40), sharex=True, sharey=True)

# Flatten the 3x3 array of subplots
axes = axes.flatten()

# Loop through each stock and create a heatmap for each year
for i, (file_path, subset) in enumerate(data.groupby(['File', 'Year'])):
    file, year = file_path
    subset_pivot = subset.pivot(index='Date', columns='File', values='Percentage Change')
    
    # Get the color for the current stock
    color = stock_colors[file]
    
    # Create a custom colormap for the stock
    cmap = ListedColormap(sns.color_palette([color]))

    # Create a heatmap with custom colors
    sns.heatmap(subset_pivot.resample('Y').last(), ax=axes[i], cmap=cmap,   annot=True, fmt=".2f")

    axes[i].set_title(f"{file.split('.')[0]} - {year}")  # Set subplot title


# Adjust layout
plt.tight_layout()
plt.show()
